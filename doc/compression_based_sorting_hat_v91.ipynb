# %% [markdown]
# ### Notebook is proof of concept: Algorithm needs refactoring (functional to OO)

# %% [markdown]
# ### Approach
# * expand attendees into independent combos of two
# * shuffle and presort list of combos so neighbors don't share elements (this prevents decimation during compression)
# * compress combos into independent small groups of specified size
# >* must filter list of available combos after each small group formation
# >(eliminate those used in small group formation plus those that are combinations of small group elements in current small group)
# * repeat until independent small groups exhausted
# * sort small groups so on a per session basis so they are independent

# %% [markdown]
# ### Issues
# * redundancy threshold parameter must be hand tuned on a case by case basis for best results (see examples below)
# * assignment of groups to sessions not yet implemented (note number of sessions is a dependent parameter)
# >* a table of possible options concerning small group size and session schedule would be helpful
# * due to combo shuffling, results vary slightly with every run
# * percentage of dropped 1:1 interactions varies by run but is consistently small when redundancy threshold is tuned correctly, can be fixed by augmenting small groups after analysis but that's klunky
# * need a sorting dashboard to summarize metrics and show performance graphically

# %%
from itertools import combinations
import random
import pandas as pd
import numpy as np
import seaborn as sns
from faker import Faker
fake = Faker()
cm=sns.color_palette("coolwarm", as_cmap=True)

# %% [markdown]
# ### inputs

# %%
large_group_size=14
small_group_size=4
redundancy_thresh=3

# %% [markdown]
# ### example 1
# 127 paired interactions 91 required, 21 small groups
# * large_group_size=14
# * small_group_size=4
# * redundancy_thresh=2
# ### example 2
# 61 paired interactions, 91 required, 10 small groups
# * large_group_size=14
# * small_group_size=4
# * redundancy_thresh=1
# ### example 3
# 69 paired interactions of 91 required, 5 groups of varying size
# * large_group_size=14
# * small_group_size=7
# * redundancy_thresh=2
# ### example 3
# 105 paired interactions of 91 required, 5 small groups
# * large_group_size=14
# * small_group_size=7
# * redundancy_thresh=3

# %%
names = [fake.unique.first_name() for i in range(large_group_size)]
#names

# %%
all_combos=list(combinations(names,2))
#all_combos

# %%
random.shuffle(all_combos)
for i in range(len(all_combos)-2):
    j=i+1
    #print(i,j)
    #look ahead for independent combo then swap with neighbor
    while len(set(all_combos[i]+all_combos[j]))<4 and j<len(all_combos)-1:    
        j += 1
    all_combos[i+1], all_combos[j] = all_combos[j], all_combos[i+1]
    #be greedy, look ahead, and try to aggregate 3 independent combos
    j=i+2
    while len(set(all_combos[i]+all_combos[i+1]+all_combos[j]))<6 and j<len(all_combos)-1:    
        j += 1
    all_combos[i+2], all_combos[j] = all_combos[j], all_combos[i+2]
    
len(all_combos)
#all_combos
# Out:
# 91

# %%
#add flag 'F', used in false_count, set to 'T' when combo is incorporated into a small group
for j in range(len(all_combos)):
    all_combos[j]=all_combos[j][:2]+tuple(['F'])

# %%
small_groups=[] #list of lists containing small groups
false_count=len(all_combos) #remaining unincorporated combos
group_idx=0 

while false_count > 0:
    combo_idx=0 #used when indexing into list of combos
    size_count=0 #tracks progress of adding individuals to small_groups
    next_small_group=[] #list that contains a candidate small group, subject to tests and modifications
  
    #begin building small groups
    while size_count < small_group_size and combo_idx<len(all_combos):
        #check to see if current combo has been used before then append it
        if(all_combos[combo_idx][2]=='F'):
            next_small_group.append(all_combos[combo_idx][0])
            next_small_group=list(set(next_small_group))
            #second individual in a group not added if small group size is odd
            if len(next_small_group)<small_group_size:
                next_small_group.append(all_combos[combo_idx][1])
                next_small_group=list(set(next_small_group))
            #flag combo as used in small group
            all_combos[combo_idx]=all_combos[combo_idx][:2]+tuple(['T'])
            false_count-=1
    
            #if more than 2 attendees of current small group are in a group already constructed 
            #remove those redundant members from current group and reset flag of current combo
            for i in range(len(small_groups)):
                if len(set(small_groups[i]).intersection(set(next_small_group)))>redundancy_thresh:
                    next_small_group=list(set(next_small_group)-set(small_groups[i]).intersection(set(next_small_group)))
                    all_combos[combo_idx]=all_combos[combo_idx][:2]+tuple(['F'])
        
            size_count=len(next_small_group)
 
        combo_idx+=1
    
    #print current small group and intersections with prior small groups
    #print(group_idx, false_count,next_small_group)
    for i in range(len(small_groups)):
        if len(set(small_groups[i]).intersection(set(next_small_group)))>redundancy_thresh:
            print('intersection between',small_groups[i],next_small_group)
    small_groups.append(next_small_group)
    group_idx+=1
  
  
    scrub_idx=0
    # filter all remaining combos contained within current small group   
    false_count=0
    while scrub_idx<len(all_combos):
        if (all_combos[scrub_idx][2]=='F'):
            if len(set(next_small_group).intersection(set(all_combos[scrub_idx])))>1:
                all_combos[scrub_idx]=all_combos[scrub_idx][:2]+tuple(['T']) 
            else:
                false_count+=1
        scrub_idx+=1
        #print(scrub_idx)

# %% [markdown]
# ### now evaluate interactions

# %%
#all_combos

# %%
df=pd.DataFrame({"Name":names})
n=0
for name in names:
  col=pd.Series(np.zeros(len(names)).T)  
  for i in range (n,len(names)):
    col[i]=0
  df = pd.concat([df, col.to_frame()],axis=1)
  df.columns.values[n+1] = name
  n=n+1

    
for combo_idx in range(len(all_combos)):
  for group_idx in range(len(small_groups)):
    if len(set(all_combos[combo_idx]).intersection(set(small_groups[group_idx])))>1:
      df.at[names.index(all_combos[combo_idx][0]),all_combos[combo_idx][1]]=group_idx+1

index = df.index
index.name = "Grouped Combos"
       
df=df.replace(0,np.NaN)
df.style.background_gradient(cmap=cm,vmin=0,vmax=len(small_groups)).highlight_null('black')
# Out:
# <style type="text/css">
# #T_0f740_row0_col1, #T_0f740_row1_col1, #T_0f740_row1_col2, #T_0f740_row1_col12, #T_0f740_row2_col1, #T_0f740_row2_col2, #T_0f740_row2_col3, #T_0f740_row3_col1, #T_0f740_row3_col2, #T_0f740_row3_col3, #T_0f740_row3_col4, #T_0f740_row4_col1, #T_0f740_row4_col2, #T_0f740_row4_col3, #T_0f740_row4_col4, #T_0f740_row4_col5, #T_0f740_row5_col1, #T_0f740_row5_col2, #T_0f740_row5_col3, #T_0f740_row5_col4, #T_0f740_row5_col5, #T_0f740_row5_col6, #T_0f740_row6_col1, #T_0f740_row6_col2, #T_0f740_row6_col3, #T_0f740_row6_col4, #T_0f740_row6_col5, #T_0f740_row6_col6, #T_0f740_row6_col7, #T_0f740_row7_col1, #T_0f740_row7_col2, #T_0f740_row7_col3, #T_0f740_row7_col4, #T_0f740_row7_col5, #T_0f740_row7_col6, #T_0f740_row7_col7, #T_0f740_row7_col8, #T_0f740_row7_col9, #T_0f740_row8_col1, #T_0f740_row8_col2, #T_0f740_row8_col3, #T_0f740_row8_col4, #T_0f740_row8_col5, #T_0f740_row8_col6, #T_0f740_row8_col7, #T_0f740_row8_col8, #T_0f740_row8_col9, #T_0f740_row8_col13, #T_0f740_row9_col1, #T_0f740_row9_col2, #T_0f740_row9_col3, #T_0f740_row9_col4, #T_0f740_row9_col5, #T_0f740_row9_col6, #T_0f740_row9_col7, #T_0f740_row9_col8, #T_0f740_row9_col9, #T_0f740_row9_col10, #T_0f740_row10_col1, #T_0f740_row10_col2, #T_0f740_row10_col3, #T_0f740_row10_col4, #T_0f740_row10_col5, #T_0f740_row10_col6, #T_0f740_row10_col7, #T_0f740_row10_col8, #T_0f740_row10_col9, #T_0f740_row10_col10, #T_0f740_row10_col11, #T_0f740_row11_col1, #T_0f740_row11_col2, #T_0f740_row11_col3, #T_0f740_row11_col4, #T_0f740_row11_col5, #T_0f740_row11_col6, #T_0f740_row11_col7, #T_0f740_row11_col8, #T_0f740_row11_col9, #T_0f740_row11_col10, #T_0f740_row11_col11, #T_0f740_row11_col12, #T_0f740_row12_col1, #T_0f740_row12_col2, #T_0f740_row12_col3, #T_0f740_row12_col4, #T_0f740_row12_col5, #T_0f740_row12_col6, #T_0f740_row12_col7, #T_0f740_row12_col8, #T_0f740_row12_col9, #T_0f740_row12_col10, #T_0f740_row12_col11, #T_0f740_row12_col12, #T_0f740_row12_col13, #T_0f740_row13_col1, #T_0f740_row13_col2, #T_0f740_row13_col3, #T_0f740_row13_col4, #T_0f740_row13_col5, #T_0f740_row13_col6, #T_0f740_row13_col7, #T_0f740_row13_col8, #T_0f740_row13_col9, #T_0f740_row13_col10, #T_0f740_row13_col11, #T_0f740_row13_col12, #T_0f740_row13_col13, #T_0f740_row13_col14 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: black;
# }
# #T_0f740_row0_col2, #T_0f740_row0_col7, #T_0f740_row1_col8, #T_0f740_row6_col8 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_0f740_row0_col3, #T_0f740_row3_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_0f740_row0_col4, #T_0f740_row0_col11, #T_0f740_row3_col9, #T_0f740_row8_col11 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_0f740_row0_col5, #T_0f740_row0_col8, #T_0f740_row0_col14, #T_0f740_row4_col8, #T_0f740_row4_col14, #T_0f740_row7_col14 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_0f740_row0_col6, #T_0f740_row0_col9, #T_0f740_row0_col10, #T_0f740_row5_col9, #T_0f740_row8_col10 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_0f740_row0_col12, #T_0f740_row2_col12 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_0f740_row0_col13, #T_0f740_row9_col13 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_0f740_row1_col3, #T_0f740_row1_col11, #T_0f740_row2_col9 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_0f740_row1_col4, #T_0f740_row1_col13, #T_0f740_row1_col14, #T_0f740_row3_col13, #T_0f740_row12_col14 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_0f740_row1_col5, #T_0f740_row1_col10 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_0f740_row1_col6, #T_0f740_row1_col7, #T_0f740_row1_col9, #T_0f740_row6_col9 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_0f740_row2_col4, #T_0f740_row2_col10, #T_0f740_row2_col14, #T_0f740_row3_col10, #T_0f740_row3_col14 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_0f740_row2_col5, #T_0f740_row2_col6, #T_0f740_row2_col8, #T_0f740_row5_col8 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_0f740_row2_col7, #T_0f740_row2_col11, #T_0f740_row2_col13, #T_0f740_row6_col11, #T_0f740_row6_col13, #T_0f740_row10_col13 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_0f740_row3_col5, #T_0f740_row3_col6, #T_0f740_row3_col11, #T_0f740_row4_col6, #T_0f740_row4_col11, #T_0f740_row5_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0f740_row3_col7, #T_0f740_row3_col12, #T_0f740_row6_col12 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_0f740_row4_col7, #T_0f740_row4_col13 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_0f740_row4_col9, #T_0f740_row4_col10, #T_0f740_row4_col12, #T_0f740_row8_col12, #T_0f740_row9_col12 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_0f740_row5_col7, #T_0f740_row5_col10, #T_0f740_row5_col14, #T_0f740_row6_col10, #T_0f740_row6_col14, #T_0f740_row9_col14 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_0f740_row5_col12, #T_0f740_row5_col13, #T_0f740_row7_col12, #T_0f740_row7_col13, #T_0f740_row11_col13 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_0f740_row7_col10, #T_0f740_row7_col11, #T_0f740_row9_col11 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_0f740_row8_col14, #T_0f740_row10_col12, #T_0f740_row10_col14, #T_0f740_row11_col14 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0f740">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f740_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_0f740_level0_col1" class="col_heading level0 col1" >Jennifer</th>
#       <th id="T_0f740_level0_col2" class="col_heading level0 col2" >Melissa</th>
#       <th id="T_0f740_level0_col3" class="col_heading level0 col3" >Sara</th>
#       <th id="T_0f740_level0_col4" class="col_heading level0 col4" >Donald</th>
#       <th id="T_0f740_level0_col5" class="col_heading level0 col5" >Kimberly</th>
#       <th id="T_0f740_level0_col6" class="col_heading level0 col6" >Christopher</th>
#       <th id="T_0f740_level0_col7" class="col_heading level0 col7" >Zachary</th>
#       <th id="T_0f740_level0_col8" class="col_heading level0 col8" >Philip</th>
#       <th id="T_0f740_level0_col9" class="col_heading level0 col9" >Brent</th>
#       <th id="T_0f740_level0_col10" class="col_heading level0 col10" >Grant</th>
#       <th id="T_0f740_level0_col11" class="col_heading level0 col11" >Sally</th>
#       <th id="T_0f740_level0_col12" class="col_heading level0 col12" >Tara</th>
#       <th id="T_0f740_level0_col13" class="col_heading level0 col13" >Matthew</th>
#       <th id="T_0f740_level0_col14" class="col_heading level0 col14" >Robert</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Grouped Combos</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f740_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f740_row0_col0" class="data row0 col0" >Jennifer</td>
#       <td id="T_0f740_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_0f740_row0_col2" class="data row0 col2" >7.000000</td>
#       <td id="T_0f740_row0_col3" class="data row0 col3" >11.000000</td>
#       <td id="T_0f740_row0_col4" class="data row0 col4" >13.000000</td>
#       <td id="T_0f740_row0_col5" class="data row0 col5" >21.000000</td>
#       <td id="T_0f740_row0_col6" class="data row0 col6" >18.000000</td>
#       <td id="T_0f740_row0_col7" class="data row0 col7" >7.000000</td>
#       <td id="T_0f740_row0_col8" class="data row0 col8

# %%
interactions=0
for combo_idx in range(len(all_combos)):
  for group_idx in range(len(small_groups)):
  
      #print('combo_idx,size_count,group_idx',combo_idx,size_count,group_idx)
      if len(set(all_combos[combo_idx]).intersection(set(small_groups[group_idx])))>1:
        interactions+=1
        print('interaction',interactions,"combo: ",combo_idx,"present in small_group: ",group_idx)
print('interactions',interactions,':',len(all_combos))
# Out:
# interaction 1 combo:  0 present in small_group:  0
# interaction 2 combo:  1 present in small_group:  0
# interaction 3 combo:  2 present in small_group:  1
# interaction 4 combo:  2 present in small_group:  5
# interaction 5 combo:  3 present in small_group:  1
# interaction 6 combo:  4 present in small_group:  2
# interaction 7 combo:  5 present in small_group:  2
# interaction 8 combo:  5 present in small_group:  21
# interaction 9 combo:  6 present in small_group:  3
# interaction 10 combo:  6 present in small_group:  16
# interaction 11 combo:  7 present in small_group:  3
# interaction 12 combo:  8 present in small_group:  4
# interaction 13 combo:  9 present in small_group:  4
# interaction 14 combo:  10 present in small_group:  5
# interaction 15 combo:  10 present in small_group:  16
# interaction 16 combo:  10 present in small_group:  18
# interaction 17 combo:  11 present in small_group:  5
# interaction 18 combo:  12 present in small_group:  6
# interaction 19 combo:  13 present in small_group:  0
# interaction 20 combo:  13 present in small_group:  15
# interaction 21 combo:  14 present in small_group:  5
# interaction 22 combo:  14 present in small_group:  7
# interaction 23 combo:  14 present in small_group:  13
# interaction 24 combo:  15 present in small_group:  6
# interaction 25 combo:  17 present in small_group:  7
# interaction 26 combo:  17 present in small_group:  20
# interaction 27 combo:  18 present in small_group:  7
# interaction 28 combo:  18 present in small_group:  9
# interaction 29 combo:  19 present in small_group:  8
# interaction 30 combo:  20 present in small_group:  3
# interaction 31 combo:  21 present in small_group:  8
# interaction 32 combo:  22 present in small_group:  6
# interaction 33 combo:  23 present in small_group:  9
# interaction 34 combo:  24 present in small_group:  5
# interaction 35 combo:  24 present in small_group:  20
# interaction 36 combo:  25 present in small_group:  9
# interaction 37 combo:  26 present in small_group:  10
# interaction 38 combo:  26 present in small_group:  19
# interaction 39 combo:  27 present in small_group:  10
# interaction 40 combo:  27 present in small_group:  12
# interaction 41 combo:  28 present in small_group:  11
# interaction 42 combo:  29 present in small_group:  11
# interaction 43 combo:  29 present in small_group:  19
# interaction 44 combo:  30 present in small_group:  9
# interaction 45 combo:  31 present in small_group:  12
# interaction 46 combo:  31 present in small_group:  21
# interaction 47 combo:  32 present in small_group:  0
# interaction 48 combo:  33 present in small_group:  12
# interaction 49 combo:  33 present in small_group:  17
# interaction 50 combo:  34 present in small_group:  13
# interaction 51 combo:  35 present in small_group:  9
# interaction 52 combo:  36 present in small_group:  6
# interaction 53 combo:  36 present in small_group:  10
# interaction 54 combo:  36 present in small_group:  20
# interaction 55 combo:  37 present in small_group:  8
# interaction 56 combo:  37 present in small_group:  17
# interaction 57 combo:  38 present in small_group:  0
# interaction 58 combo:  39 present in small_group:  1
# interaction 59 combo:  39 present in small_group:  14
# interaction 60 combo:  39 present in small_group:  15
# interaction 61 combo:  40 present in small_group:  13
# interaction 62 combo:  41 present in small_group:  12
# interaction 63 combo:  42 present in small_group:  13
# interaction 64 combo:  43 present in small_group:  14
# interaction 65 combo:  43 present in small_group:  19
# interaction 66 combo:  43 present in small_group:  20
# interaction 67 combo:  44 present in small_group:  14
# interaction 68 combo:  45 present in small_group:  13
# interaction 69 combo:  45 present in small_group:  16
# interaction 70 combo:  46 present in small_group:  15
# interaction 71 combo:  47 present in small_group:  15
# interaction 72 combo:  47 present in small_group:  17
# interaction 73 combo:  48 present in small_group:  2
# interaction 74 combo:  49 present in small_group:  1
# interaction 75 combo:  49 present in small_group:  13
# interaction 76 combo:  50 present in small_group:  11
# interaction 77 combo:  51 present in small_group:  16
# interaction 78 combo:  52 present in small_group:  7
# interaction 79 combo:  53 present in small_group:  16
# interaction 80 combo:  54 present in small_group:  17
# interaction 81 combo:  54 present in small_group:  18
# interaction 82 combo:  55 present in small_group:  10
# interaction 83 combo:  56 present in small_group:  1
# interaction 84 combo:  56 present in small_group:  7
# interaction 85 combo:  57 present in small_group:  3
# interaction 86 combo:  57 present in small_group:  5
# interaction 87 combo:  57 present in small_group:  17
# interaction 88 combo:  58 present in small_group:  4
# interaction 89 combo:  59 present in small_group:  7
# interaction 90 combo:  59 present in small_group:  18
# interaction 91 combo:  60 present in small_group:  14
# interaction 92 combo:  61 present in small_group:  17
# interaction 93 combo:  63 present in small_group:  14
# interaction 94 combo:  64 present in small_group:  3
# interaction 95 combo:  64 present in small_group:  10
# interaction 96 combo:  65 present in small_group:  18
# interaction 97 combo:  66 present in small_group:  18
# interaction 98 combo:  67 present in small_group:  14
# interaction 99 combo:  67 present in small_group:  21
# interaction 100 combo:  68 present in small_group:  6
# interaction 101 combo:  68 present in small_group:  8
# interaction 102 combo:  69 present in small_group:  19
# interaction 103 combo:  70 present in small_group:  15
# interaction 104 combo:  71 present in small_group:  6
# interaction 105 combo:  72 present in small_group:  11
# interaction 106 combo:  73 present in small_group:  3
# interaction 107 combo:  73 present in small_group:  15
# interaction 108 combo:  74 present in small_group:  19
# interaction 109 combo:  76 present in small_group:  1
# interaction 110 combo:  77 present in small_group:  20
# interaction 111 combo:  78 present in small_group:  10
# interaction 112 combo:  78 present in small_group:  16
# interaction 113 combo:  79 present in small_group:  20
# interaction 114 combo:  80 present in small_group:  19
# interaction 115 combo:  80 present in small_group:  21
# interaction 116 combo:  81 present in small_group:  12
# interaction 117 combo:  82 present in small_group:  4
# interaction 118 combo:  82 present in small_group:  9
# interaction 119 combo:  83 present in small_group:  2
# interaction 120 combo:  83 present in small_group:  8
# interaction 121 combo:  83 present in small_group:  18
# interaction 122 combo:  84 present in small_group:  4
# interaction 123 combo:  84 present in small_group:  8
# interaction 124 combo:  85 present in small_group:  2
# interaction 125 combo:  86 present in small_group:  11
# interaction 126 combo:  87 present in small_group:  0
# interaction 127 combo:  87 present in small_group:  4
# interaction 128 combo:  87 present in small_group:  12
# interaction 129 combo:  88 present in small_group:  21
# interaction 130 combo:  89 present in small_group:  2
# interaction 131 combo:  89 present in small_group:  11
# interaction 132 combo:  90 present in small_group:  21
# interactions 132 : 91

# %%
small_groups
# Out:
# [['Robert', 'Brent', 'Tara', 'Sally'],
#  ['Matthew', 'Kimberly', 'Grant', 'Melissa'],
#  ['Zachary', 'Donald', 'Tara', 'Christopher'],
#  ['Tara', 'Jennifer', 'Grant', 'Sara'],
#  ['Sara', 'Brent', 'Melissa', 'Sally'],
#  ['Robert', 'Matthew', 'Jennifer', 'Grant'],
#  ['Zachary', 'Jennifer', 'Philip', 'Melissa'],
#  ['Robert', 'Matthew', 'Zachary', 'Kimberly'],
#  ['Zachary', 'Brent', 'Melissa', 'Christopher'],
#  ['Matthew', 'Zachary', 'Sara', 'Sally'],
#  ['Philip', 'Jennifer', 'Donald', 'Sara'],
#  ['Matthew', 'Philip', 'Christopher', 'Tara'],
#  ['Jennifer', 'Donald', 'Brent', 'Sally'],
#  ['Matthew', 'Robert', 'Donald', 'Melissa'],
#  ['Philip', 'Kimberly', 'Grant', 'Sally'],
#  ['Grant', 'Kimberly', 'Brent', 'Tara'],
#  ['Robert', 'Sara', 'Donald', 'Grant'],
#  ['Jennifer', 'Brent', 'Grant', 'Christopher'],
#  ['Robert', 'Zachary', 'Grant', 'Christopher'],
#  ['Philip', 'Sara', 'Kimberly', 'Christopher'],
#  ['Robert', 'Jennifer', 'Philip', 'Kimberly'],
#  ['Christopher', 'Donald', 'Kimberly', 'Sally']]
